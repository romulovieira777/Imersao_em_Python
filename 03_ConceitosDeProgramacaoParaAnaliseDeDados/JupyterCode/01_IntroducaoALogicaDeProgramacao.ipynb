# %% [markdown]
# # variáveis
# # Tipos de dados em Python
#
# # 1. Caracter
# # Um único caractere, por exemplo: 'a', 'b', '1'
#
# # 2. String
# # Uma sequência de caracteres, por exemplo: "Olá, Mundo!", "Python 3.9"
#
# # 3. Boolean
# # Representa valores de verdade, True ou False, por exemplo:
# # is_active = True
#
# # 4. Números
# # Inteiros e flutuantes, por exemplo:
# # inteiro = 10
# # flutuante = 10.5
#
# # 5. Vetor
# # Uma coleção de elementos de um único tipo, por exemplo:
# # vetor = [1, 2, 3, 4]
#
# # 6. Lista
# # Uma coleção ordenada e mutável de elementos, por exemplo:
# # lista = [1, "texto", 3.14, True]
#
# # 7. Matrizes
# # Estruturas de dados bidimensionais, por exemplo:
# # matriz = [[1, 2, 3], [4, 5, 6]]
#
# # 8. DataFrame
# # Estruturas de dados tabulares, geralmente usadas com a biblioteca pandas, por exemplo:
# # import pandas as pd
# # df = pd.DataFrame({'Coluna1': [1, 2], 'Coluna2': [3, 4]})
#
# # 9. Tuplas
# # Coleções ordenadas e imutáveis de elementos, por exemplo:
# # tupla = (1, "texto", 3.14)
#
# # 10. Condicional
# # Estruturas de controle de fluxo, por exemplo:
# # if condicao:
# # print("Condição verdadeira")
# # else:
# # print("Condição falsa")
#
# # Iterações
# # Estruturas de repetição, por exemplo:
# # for i in range(5):
# # print(i)
#
# # while condicao:
# # print("Repetindo enquanto a condição for verdadeira")
